# %% [markdown]
# # Models

# %% [markdown]
# ## LLMs

# %% [markdown]
# Modelos de Linguagem Grande (LLMs, na sigla em inglês) são um componente central do LangChain. O LangChain não fornece seus próprios LLMs, mas sim oferece uma interface padrão para interagir com diversos LLMs diferentes. Para ser específico, essa interface é uma que recebe como entrada uma string e retorna uma string.
#
# Existem muitos provedores de LLMs (OpenAI, Cohere, Hugging Face, etc) - a classe LLM é projetada para fornecer uma interface padrão para todos eles.

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# from langchain_openai import OpenAI
from langchain_google_genai import GoogleGenerativeAI


# 2.1 Inicializando o modelo de linguagem Gemini
llm = GoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.5,
    google_api_key=os.getenv("GOOGLE_API_KEY"),
)
# Out:
# c:\Users\Campeao Lub\OneDrive - Campeão Distribuição e Logística Ltda\Documentos\GitHub\octo\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %% [markdown]
# ### Chamando a llm

# %%
pergunta = 'Conte uma história breve sobre a jornada de aprender a programar'
llm.invoke(pergunta)
# Out:
# 'O cursor piscava, implacável, na tela. Ana encarava o editor de texto como se fosse um enigma indecifrável. "Olá Mundo", digitou, hesitante. Aquele era o primeiro passo, o mantra de todo aspirante a programador. Mas o "Olá Mundo" não parecia tão amigável quanto imaginava.\n\nNo começo, era uma selva de termos estranhos: variáveis, loops, funções. Ana se sentia perdida em um labirinto de sintaxes e erros. Cada linha de código era uma batalha, e cada erro, uma derrota humilhante. As noites eram longas, regadas a café e tutoriais online. A frustração era constante, a vontade de desistir, quase irresistível.\n\nMas Ana era persistente. Ela se agarrou à promessa de criar algo do nada, de dar vida a ideias com linhas de código. Começou com pequenos projetos: um conversor de moedas, um jogo simples de adivinhação. A cada projeto finalizado, a cada bug corrigido, a cada linha de código que funcionava, a frustração diminuía e a confiança crescia.\n\nAos poucos, a selva começou a se tornar um jardim. Ana aprendeu a ler o código como se fosse uma língua estrangeira, a entender a lógica por trás das instruções. Descobriu a beleza da programação, a elegância de um algoritmo bem construído, a satisfação de resolver um problema complexo.\n\nUm dia, Ana se pegou criando um aplicativo para ajudar sua avó a organizar seus remédios. Era algo simples, mas funcional, algo que realmente fazia a diferença. Naquele momento, ela percebeu que a jornada valera a pena. O cursor ainda piscava na tela, mas agora, Ana sabia o que escrever. Ela não era mais uma novata perdida, mas sim uma programadora, uma criadora, uma solucionadora de problemas. E o "Olá Mundo" agora soava como uma promessa, não um desafio. A promessa de um futuro cheio de possibilidades, construído linha a linha, com a força da sua própria determinação.'

# %% [markdown]
# ### Chamando com stream de resposta

# %%
pergunta = 'Conte uma história breve sobre a jornada de aprender a programar'
for trecho in llm.stream(pergunta):
    print(trecho, end='')
# Out:
# O cursor piscava, implacável, na tela branca. Ana, com seus vinte e poucos anos e uma pilha de tutoriais desorganizados, sentia um frio na espinha. "Olá, Mundo!" era o objetivo, a porta de entrada para um universo que parecia indecifrável.
#
# No começo, a programação era uma língua estrangeira, cheia de sintaxes bizarras e erros misteriosos. Cada ponto e vírgula fora do lugar era um muro intransponível. A frustração era constante, a vontade de desistir, uma sombra persistente.
#
# Mas Ana era teimosa. Ela se juntou a fóruns online, onde outros aprendizes compartilhavam suas dores e vitórias. Descobriu a alegria de resolver um bug, a satisfação de ver um programa rodar pela primeira vez.
#
# As madrugadas se estenderam, iluminadas pela tela do computador. Ana aprendeu sobre loops, funções, classes, objetos. A lógica começou a fazer sentido, as linhas de código se tornaram ferramentas, e a tela branca, um campo fértil para a sua criatividade.
#
# Um dia, Ana criou um pequeno jogo, simples, mas seu. Um jogo que funcionava, que divertia, que era a prova tangível de sua jornada. Aquele cursor que antes a intimidava, agora era um convite. A programação não era mais uma língua estrangeira, mas um dialeto que ela estava aprendendo a dominar, uma ferramenta para construir o futuro, linha por linha. E ela, finalmente, se sentia em casa.

# %% [markdown]
# ### Chamadas simultâneas

# %%
perguntas = [
    'O que é o tessa?',
    'O que é a mundo?',
    'O que é o universo?'
]

llm.batch(perguntas)
# Out:
# ['"Tessa" pode se referir a várias coisas, dependendo do contexto. Aqui estão algumas das possibilidades mais comuns:\n\n*   **Nome próprio:** Tessa é um nome feminino, geralmente considerado um diminutivo de Theresa ou uma variação de Tess.\n\n*   **TESS (Transiting Exoplanet Survey Satellite):** Um satélite da NASA lançado em 2018 com o objetivo de descobrir novos exoplanetas (planetas fora do nosso sistema solar) que orbitam estrelas brilhantes próximas.\n\n*   **Outros usos:** Pode haver outros usos menos comuns, como nomes de empresas, produtos ou personagens fictícios.\n\nPara entender a qual "Tessa" você se refere, preciso de mais contexto. Por favor, forneça mais informações sobre onde você ouviu ou leu esse nome. Por exemplo:\n\n*   Você viu o nome em um artigo de notícias sobre ciência?\n*   Você ouviu o nome em uma conversa sobre nomes de bebês?\n*   Você viu o nome em um livro ou filme?\n\nCom mais informações, posso fornecer uma resposta mais precisa.',
#  'A palavra "mundo" pode ter diversos significados, dependendo do contexto em que é utilizada. Aqui estão alguns dos principais:\n\n**1. Planeta Terra:**\n\n*   Este é o sentido mais comum. "Mundo" se refere ao planeta em que vivemos, com sua geografia, ecossistemas, populações e tudo o que o compõe.\n\n**2. Humanidade:**\n\n*   "Mundo" pode se referir à totalidade dos seres humanos, à sociedade global e à civilização humana.\n\n**3. Uma esfera ou domínio específico:**\n\n*   Pode se referir a um campo de atividade, interesse ou experiência particular. Por exemplo:\n    *   "O mundo da música"\n    *   "O mundo dos negócios"\n    *   "O mundo da moda"\n\n**4. Uma perspectiva ou realidade pessoal:**\n\n*   Pode se referir à maneira como uma pessoa percebe e interpreta a realidade ao seu redor. Por exemplo:\n    *   "Cada um vive no seu próprio mundo."\n\n**5. Universo:**\n\n*   Em um sentido mais amplo, "mundo" pode se referir ao universo como um todo, incluindo todos os planetas, estrelas e galáxias.\n\n**Em resumo, o significado de "mundo" é flexível e depende do contexto. Para entender o que a pessoa quer dizer ao usar essa palavra, é importante considerar a situação em que ela está sendo utilizada.**\n\nSe você tiver um contexto específico em mente, posso te dar uma definição mais precisa.',
#  'O universo é tudo o que existe: toda a matéria, energia, espaço e tempo. É um sistema vasto e em constante expansão que contém desde as menores partículas subatômicas até as maiores estruturas cósmicas, como galáxias e aglomerados de galáxias.\n\nPara entender melhor, podemos dividir o universo em alguns componentes principais:\n\n*   **Matéria:** Tudo que tem massa e ocupa espaço. Inclui planetas, estrelas, galáxias, poeira cósmica, e até mesmo nós.\n*   **Energia:** A capacidade de realizar trabalho. No universo, a energia se manifesta em diversas formas, como luz, calor, radiação e energia escura.\n*   **Espaço:** O "palco" onde toda a matéria e energia existem e interagem. O espaço não é vazio, mas sim uma entidade dinâmica que pode se expandir e se curvar.\n*   **Tempo:** A dimensão que permite que eventos ocorram em uma sequência. O tempo está intrinsecamente ligado ao espaço, formando o que chamamos de espaço-tempo.\n\n**Alguns pontos importantes sobre o universo:**\n\n*   **Tamanho:** O tamanho exato do universo é desconhecido. O universo observável, que é a porção que podemos ver da Terra, tem um diâmetro de cerca de 93 bilhões de anos-luz. No entanto, o universo total pode ser muito maior, possivelmente infinito.\n*   **Idade:** Estima-se que o universo tenha cerca de 13,8 bilhões de anos. Essa idade é baseada em medições da radiação cósmica de fundo e da taxa de expansão do universo.\n*   **Composição:** A composição do universo é surpreendente. Apenas cerca de 5% do universo é composto de matéria bariônica (a matéria "normal" que conhecemos). Cerca de 27% é composto de matéria escura, uma forma misteriosa de matéria que não interage com a luz. E cerca de 68% é composto de energia escura, uma força misteriosa que está acelerando a expansão do universo.\n*   **Evolução:** O universo está em constante evolução. Desde o Big Bang, o universo tem se expandido e esfriado, permitindo a formação de estrelas, galáxias e planetas.\n\nO estudo do universo é feito por meio da astronomia e da cosmologia. Essas áreas da ciência utilizam telescópios, satélites e modelos teóricos para investigar a origem, a estrutura, a evolução e o destino do universo.\n\nÉ importante notar que nossa compreensão do universo ainda é incompleta. Há muitas perguntas sem resposta e muitos mistérios a serem desvendados. A busca por conhecimento sobre o universo é uma das maiores aventuras da ciência moderna.']

# %%
# llm.batch(perguntas)

# %% [markdown]
# ## ChatModels

# %% [markdown]
# ChatModels são um componente central do LangChain.
#
# Um modelo de chat é um modelo de linguagem que utiliza mensagens de chat como entradas e retorna mensagens de chat como saídas (ao invés de usar texto puro).
#
# O LangChain possui integrações com vários provedores de modelos (OpenAI, Cohere, Hugging Face, etc.) e expõe uma interface padrão para interagir com todos esses modelos.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI 

chat = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# %%
# from langchain_openai import ChatOpenAI

# chat = ChatOpenAI(model='gpt-3.5-turbo-0125')

# %%
from langchain_core.messages import HumanMessage, SystemMessage

mensagens = [
    SystemMessage(content='Você é um assistente que conta piadas.'),
    HumanMessage(content='Quanto é 1 + 1?')
]
resposta = chat.invoke(mensagens)

# %%
print(resposta.content)
# Out:
# Depende. No meu caso, 1 + 1 = 2. Mas na sua cabeça, 1 + 1 = uma dor de cabeça!

# %%
resposta.response_metadata
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.0-flash',
#  'safety_ratings': [],
#  'model_provider': 'google_genai'}

# %%
# Usando OpenAI, a resposta é retornada em um único trecho, mesmo usando stream()
# from langchain_core.messages import HumanMessage, SystemMessage
""" 
mensagens = [
    SystemMessage(content='Você é um assistente que conta piadas.'),
    HumanMessage(content='Quanto é 1 + 1?')
]
for trecho in chat.stream(mensagens):
    print(trecho.content, end='')
"""

# Depende, você está usando a matemática ou a lógica das piadas? Se for matemática, a resposta é 2. 
# Mas se for lógica de piadas, a resposta é 11!
# Out:
# Depende. Numa sala de aula, é 2. Numa equipa de futebol, é 11.

# %%
# com gemini 2.0-flash, a resposta é retornada em um único trecho, mesmo usando stream()
from langchain_core.messages import HumanMessage, SystemMessage

mensagens = [
    SystemMessage(content='Você é um assistente que conta piadas.'),
    HumanMessage(content='Quanto é 1 + 1?')
]
for trecho in chat.stream(mensagens):
    print(trecho.content, end='')
# Out:
# Depende. Na maioria das vezes, é 2. Mas às vezes, é 11.

# %% [markdown]
# Existem 5 tipos diferentes de mensagens:
#
# - `HumanMessage`: Isso representa uma mensagem do usuário. Geralmente consiste apenas de conteúdo.
#
# - `AIMessage`: Isso representa uma mensagem do modelo. Pode ter additional_kwargs incluídos - por exemplo, tool_calls se estiver usando chamadas de ferramentas da OpenAI.
#
# - `SystemMessage`: Isso representa uma mensagem do sistema, que indica ao modelo como se comportar. Geralmente consiste apenas de conteúdo. Nem todo modelo suporta isso.
#
# - `FunctionMessage`: Isso representa o resultado de uma chamada de função. Além do papel e conteúdo, esta mensagem tem um parâmetro de nome que transmite o nome da função que foi chamada para produzir este resultado.
#
# - `ToolMessage`: Isso representa o resultado de uma chamada de ferramenta. Isso é distinto de uma Mensagem de Função a fim de corresponder aos tipos de mensagens de função e ferramenta da OpenAI. Além do papel e conteúdo, esta mensagem tem um parâmetro tool_call_id que transmite o id da chamada à ferramenta que foi feita para produzir este resultado.
